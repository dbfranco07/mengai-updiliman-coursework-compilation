# %% [markdown]
# # Package Import

# %%
from ucimlrepo import fetch_ucirepo 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from autosklearn.classification import AutoSklearnClassifier
import optuna

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Data import and Split

# %%
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697) 
X = predict_students_dropout_and_academic_success.data.features 
y = predict_students_dropout_and_academic_success.data.targets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y.to_numpy().ravel(),
    test_size=0.25,
    stratify=y,
    random_state=42
)

# %% [markdown]
# # AutoML

# %%
automl = AutoSklearnClassifier(
    time_left_for_this_task=120,
)

# %%
automl.fit(X_train, y_train)
# Out:
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       per_run_time_limit=12, time_left_for_this_task=120)

# %%
automl.leaderboard()
# Out:
#           rank  ensemble_weight                type      cost  duration
# model_id
# 2            1             0.46       random_forest  0.229224  2.962476
# 3            2             0.06       random_forest  0.243836  3.560432
# 7            3             0.06   gradient_boosting  0.249315  7.621041
# 6            4             0.24  passive_aggressive  0.263927  0.799533
# 11           5             0.08       random_forest  0.264840  2.749202
# 12           6             0.10                 mlp  0.295890  7.538225

# %%
y_pred_ensemble = automl.predict(X_test)

# %%
ensemble_accuracy = accuracy_score(y_test, y_pred_ensemble)
print("Auto-Sklearn Ensemble Accuracy:", ensemble_accuracy)
# Out:
# Auto-Sklearn Ensemble Accuracy: 0.7585895117540687

# %% [markdown]
# # Bayesian Optimization

# %%
col_ohe = [
    'Marital Status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation",
]

columntransfomer = ColumnTransformer(
    [
        ('ohe', OneHotEncoder(sparse=False, handle_unknown='ignore'), col_ohe),
    ], 
    remainder='passthrough'
)

# %%
X_train_prep = columntransfomer.fit_transform(X_train)
X_train_prep
# Out:
# array([[ 1.  ,  0.  ,  0.  , ..., 15.5 ,  2.8 , -4.06],
#        [ 1.  ,  0.  ,  0.  , ..., 12.4 ,  0.5 ,  1.79],
#        [ 1.  ,  0.  ,  0.  , ..., 11.1 ,  0.6 ,  2.02],
#        ...,
#        [ 1.  ,  0.  ,  0.  , ..., 12.7 ,  3.7 , -1.7 ],
#        [ 1.  ,  0.  ,  0.  , ...,  8.9 ,  1.4 ,  3.51],
#        [ 1.  ,  0.  ,  0.  , ...,  7.6 ,  2.6 ,  0.32]])

# %%
X_test_prep = columntransfomer.transform(X_test)
X_test_prep
# Out:
# array([[ 1.  ,  0.  ,  0.  , ...,  9.4 , -0.8 , -3.12],
#        [ 1.  ,  0.  ,  0.  , ..., 10.8 ,  1.4 ,  1.74],
#        [ 1.  ,  0.  ,  0.  , ..., 11.1 ,  0.6 ,  2.02],
#        ...,
#        [ 1.  ,  0.  ,  0.  , ..., 12.7 ,  3.7 , -1.7 ],
#        [ 1.  ,  0.  ,  0.  , ...,  9.4 , -0.8 , -3.12],
#        [ 1.  ,  0.  ,  0.  , ..., 13.9 , -0.3 ,  0.79]])

# %%
def objective(trial):
    # Define the hyperparameter search space
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]), 
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy"]),
        "class_weight": trial.suggest_categorical("class_weight", [None, "balanced"]),
    }

    # Initialize the model with current hyperparameters
    model = RandomForestClassifier(**param, random_state=42)

    # Train the model
    model.fit(X_train_prep, y_train)

    # Evaluate the model
    preds = model.predict(X_test_prep)
    accuracy = accuracy_score(y_test, preds)

    return accuracy

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2024-11-28 04:21:16,572] A new study created in memory with name: no-name-d7af1f3e-b33b-44e4-90b2-0cf6bcc091e5
# [I 2024-11-28 04:21:17,218] Trial 0 finished with value: 0.7377938517179023 and parameters: {'n_estimators': 227, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.7377938517179023.
# [I 2024-11-28 04:21:23,784] Trial 1 finished with value: 0.7251356238698011 and parameters: {'n_estimators': 379, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': None}. Best is trial 0 with value: 0.7377938517179023.
# [I 2024-11-28 04:21:34,413] Trial 2 finished with value: 0.6600361663652803 and parameters: {'n_estimators': 302, 'max_depth': 19, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.7377938517179023.
# [I 2024-11-28 04:21:35,238] Trial 3 finished with value: 0.7396021699819169 and parameters: {'n_estimators': 259, 'max_depth': 19, 'min_samples_split': 10, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.7396021699819169.
# [I 2024-11-28 04:21:36,580] Trial 4 finished with value: 0.7603978300180831 and parameters: {'n_estimators': 254, 'max_depth': 19, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7603978300180831.
# [I 2024-11-28 04:21:49,386] Trial 5 finished with value: 0.6654611211573237 and parameters: {'n_estimators': 498, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7603978300180831.
# [I 2024-11-28 04:21:48,879] Trial 6 finished with value: 0.6907775768535263 and parameters: {'n_estimators': 393, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 4 with value: 0.7603978300180831.
# [I 2024-11-28 04:21:49,729] Trial 7 finished with value: 0.7386980108499096 and parameters: {'n_estimators': 395, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 11, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7603978300180831.
# [I 2024-11-28 04:22:03,340] Trial 8 finished with value: 0.6564195298372514 and parameters: {'n_estimators': 362, 'max_depth': 17, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7603978300180831.
# [I 2024-11-28 04:22:09,990] Trial 9 finished with value: 0.7667269439421338 and parameters: {'n_estimators': 309, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 9 with value: 0.7667269439421338.
# [I 2024-11-28 04:22:12,148] Trial 10 finished with value: 0.7676311030741411 and parameters: {'n_estimators': 115, 'max_depth': 14, 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:14,294] Trial 11 finished with value: 0.7649186256781193 and parameters: {'n_estimators': 116, 'max_depth': 14, 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:15,367] Trial 12 finished with value: 0.7603978300180831 and parameters: {'n_estimators': 55, 'max_depth': 14, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:17,292] Trial 13 finished with value: 0.7667269439421338 and parameters: {'n_estimators': 159, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:20,324] Trial 14 finished with value: 0.7649186256781193 and parameters: {'n_estimators': 193, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:21,014] Trial 15 finished with value: 0.7197106690777577 and parameters: {'n_estimators': 320, 'max_depth': 16, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:23,458] Trial 16 finished with value: 0.7640144665461122 and parameters: {'n_estimators': 125, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 12, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:32,242] Trial 17 finished with value: 0.759493670886076 and parameters: {'n_estimators': 470, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:32,402] Trial 18 finished with value: 0.7269439421338155 and parameters: {'n_estimators': 60, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:33,076] Trial 19 finished with value: 0.7468354430379747 and parameters: {'n_estimators': 201, 'max_depth': 17, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:39,027] Trial 20 finished with value: 0.759493670886076 and parameters: {'n_estimators': 324, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 10 with value: 0.7676311030741411.
# [I 2024-11-28 04:22:41,682] Trial 21 finished with value: 0.7685352622061483 and parameters: {'n_estimators': 152, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 21 with value: 0.7685352622061483.
# [I 2024-11-28 04:22:43,485] Trial 22 finished with value: 0.7703435804701627 and parameters: {'n_estimators': 102, 'max_depth': 15, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 22 with value: 0.7703435804701627.
# [I 2024-11-28 04:22:45,394] Trial 23 finished with value: 0.7721518987341772 and parameters: {'n_estimators': 109, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:44,729] Trial 24 finished with value: 0.7676311030741411 and parameters: {'n_estimators': 82, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:47,408] Trial 25 finished with value: 0.7658227848101266 and parameters: {'n_estimators': 149, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:50,499] Trial 26 finished with value: 0.7613019891500904 and parameters: {'n_estimators': 174, 'max_depth': 12, 'min_samples_split': 17, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:52,183] Trial 27 finished with value: 0.7658227848101266 and parameters: {'n_estimators': 92, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:52,484] Trial 28 finished with value: 0.7142857142857143 and parameters: {'n_estimators': 134, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:53,130] Trial 29 finished with value: 0.7251356238698011 and parameters: {'n_estimators': 222, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:53,413] Trial 30 finished with value: 0.7386980108499096 and parameters: {'n_estimators': 87, 'max_depth': 16, 'min_samples_split': 18, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:55,267] Trial 31 finished with value: 0.7676311030741411 and parameters: {'n_estimators': 98, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:22:58,541] Trial 32 finished with value: 0.7640144665461122 and parameters: {'n_estimators': 183, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:00,563] Trial 33 finished with value: 0.7676311030741411 and parameters: {'n_estimators': 111, 'max_depth': 15, 'min_samples_split': 13, 'min_samples_leaf': 17, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:05,445] Trial 34 finished with value: 0.7224231464737794 and parameters: {'n_estimators': 146, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 14, 'max_features': None, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:06,684] Trial 35 finished with value: 0.7694394213381555 and parameters: {'n_estimators': 70, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:08,629] Trial 36 finished with value: 0.6817359855334539 and parameters: {'n_estimators': 66, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:09,304] Trial 37 finished with value: 0.7341772151898734 and parameters: {'n_estimators': 229, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:10,289] Trial 38 finished with value: 0.6754068716094033 and parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:13,019] Trial 39 finished with value: 0.7631103074141049 and parameters: {'n_estimators': 273, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:13,245] Trial 40 finished with value: 0.7377938517179023 and parameters: {'n_estimators': 78, 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:15,210] Trial 41 finished with value: 0.7703435804701627 and parameters: {'n_estimators': 109, 'max_depth': 14, 'min_samples_split': 17, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:18,184] Trial 42 finished with value: 0.7676311030741411 and parameters: {'n_estimators': 163, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:20,724] Trial 43 finished with value: 0.7631103074141049 and parameters: {'n_estimators': 139, 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:22,376] Trial 44 finished with value: 0.7703435804701627 and parameters: {'n_estimators': 94, 'max_depth': 14, 'min_samples_split': 17, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:24,303] Trial 45 finished with value: 0.7703435804701627 and parameters: {'n_estimators': 106, 'max_depth': 16, 'min_samples_split': 17, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:26,352] Trial 46 finished with value: 0.7649186256781193 and parameters: {'n_estimators': 109, 'max_depth': 18, 'min_samples_split': 17, 'min_samples_leaf': 17, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:28,592] Trial 47 finished with value: 0.7622061482820977 and parameters: {'n_estimators': 122, 'max_depth': 16, 'min_samples_split': 18, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:30,430] Trial 48 finished with value: 0.7685352622061483 and parameters: {'n_estimators': 101, 'max_depth': 17, 'min_samples_split': 18, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 23 with value: 0.7721518987341772.
# [I 2024-11-28 04:23:31,342] Trial 49 finished with value: 0.7341772151898734 and parameters: {'n_estimators': 218, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 23 with value: 0.7721518987341772.

# %%
print("Best hyperparameters:", study.best_params)
print("Best accuracy:", study.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 109, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}
# Best accuracy: 0.7721518987341772

# %%
best_params = study.best_params
opt = RandomForestClassifier(**best_params, random_state=42)
opt.fit(X_train_prep, y_train)

final_accuracy = accuracy_score(y_test, opt.predict(X_test_prep))
print("Final accuracy with optimized GradientBoostingClassifier:", final_accuracy)
# Out:
# Final accuracy with optimized GradientBoostingClassifier: 0.7721518987341772

# %% [markdown]
# # Inference Time

# %%
import time

# Measure inference time for Auto-Sklearn ensemble
start_time = time.time()
automl.predict(X_test)
ensemble_inference_time = time.time() - start_time
print("Auto-Sklearn Ensemble Inference Time:", ensemble_inference_time)

# Measure inference time for the optimized model
start_time = time.time()
opt.predict(X_test_prep)
optimized_inference_time = time.time() - start_time
print("Optimized Model Inference Time:", optimized_inference_time)
# Out:
# Auto-Sklearn Ensemble Inference Time: 0.39054441452026367
# Optimized Model Inference Time: 0.021266460418701172

# %% [markdown]
# # Permutation Importance

# %%
# Permutation importance for Auto-Sklearn ensemble
ensemble_importances = permutation_importance(automl, X_test, y_test, n_repeats=10, random_state=42)
print("Ensemble Feature Importances:", ensemble_importances.importances_mean)

# Permutation importance for optimized model
optimized_importances = permutation_importance(opt, X_test_prep, y_test, n_repeats=10, random_state=42)
print("Optimized Model Feature Importances:", optimized_importances.importances_mean)
# Out:
# Ensemble Feature Importances: [-2.98372514e-03 -2.53164557e-03 -5.42495479e-04  2.26039783e-03
#  -9.04159132e-05  3.88788427e-03  2.26039783e-03 -5.42495479e-04
#  -3.25497288e-03 -5.15370705e-03 -3.52622061e-03 -1.98915009e-03
#  -3.07414105e-03 -4.52079566e-03 -1.08499096e-03  3.07414105e-03
#   4.12296564e-02 -4.24954792e-03 -1.08499096e-03  4.97287523e-03
#   0.00000000e+00 -2.71247740e-04  1.26582278e-03  1.62748644e-03
#   4.23146474e-02 -3.70705244e-03  1.35623870e-03  9.04159132e-05
#   5.78661844e-03 -5.78661844e-03  1.73688969e-01  1.36528029e-02
#  -9.94575045e-04 -3.34538879e-03  2.53164557e-03 -9.04159132e-04]
# Optimized Model Feature Importances: [ 0.00000000e+00  9.04159132e-05  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  2.98372514e-03  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  2.16998192e-03  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -2.71247740e-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  7.23327306e-04  9.04159132e-05  0.00000000e+00
#   0.00000000e+00 -1.80831826e-04  0.00000000e+00  0.00000000e+00
#   4.52079566e-04  3.25497288e-03  0.00000000e+00  7.23327306e-04
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  2.89330922e-03
#   9.04159132e-04  1.26582278e-03  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  4.52079566e-04
#   0.00000000e+00  7.23327306e-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  9.04159132e-05
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  4.52079566e-04
#   9.04159132e-05  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  6.32911392e-04  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.80831826e-04  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   8.13743219e-04  1.08499096e-03  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   2.35081374e-03  5.42495479e-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  7.23327306e-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   1.98915009e-03  0.00000000e+00  7.86618445e-03  7.41410488e-03
#   2.98372514e-03  0.00000000e+00  7.23327306e-04  5.26220615e-02
#   3.97830018e-03  2.26039783e-03  1.83544304e-02  0.00000000e+00
#   9.04159132e-05  4.79204340e-03  1.20253165e-02  1.31103074e-02
#   6.69077758e-03  0.00000000e+00  9.04159132e-05  1.18444846e-02
#   9.40325497e-03  2.63924051e-01  7.23327306e-03  0.00000000e+00
#   4.33996383e-03  1.02169982e-02  3.25497288e-03]

# %%
ensemble_importances.keys()
# Out:
# dict_keys(['importances_mean', 'importances_std', 'importances'])

# %%
im = ensemble_importances.importances_mean
plt.figure(figsize=(10, 10))
plt.barh(X_train.columns, im)
# Out:
# <BarContainer object of 36 artists>

# %%
top_indices = np.argsort(np.abs(im))[-10:][::-1]
top_feature_importance = im[top_indices]
top_feature = np.array(X_train.columns)[top_indices]
top_features_auto_df = pd.DataFrame({'AutoML Feature': top_feature, 'AutoML importance': top_feature_importance})
top_features_auto_df
# Out:
#                            AutoML Feature  AutoML importance
# 0     Curricular units 2nd sem (approved)           0.173689
# 1     Curricular units 1st sem (approved)           0.042315
# 2                 Tuition fees up to date           0.041230
# 3        Curricular units 2nd sem (grade)           0.013653
# 4     Curricular units 2nd sem (enrolled)           0.005787
# 5  Curricular units 2nd sem (evaluations)          -0.005787
# 6                  Father's qualification          -0.005154
# 7                       Age at enrollment           0.004973
# 8                               Displaced          -0.004521
# 9                                  Gender          -0.004250

# %%
im2 = optimized_importances.importances_mean
plt.figure(figsize=(10, 50))
plt.barh(columntransfomer.get_feature_names(), im2)
# Out:
# <BarContainer object of 231 artists>

# %%
top_indices = np.argsort(np.abs(im2))[-10:][::-1]
top_feature_importance = im2[top_indices]
top_feature = np.array(columntransfomer.get_feature_names())[top_indices]
top_features_opti_df = pd.DataFrame({'BayesianOpti Feature': top_feature, 'BayesianOpti Importance': top_feature_importance})
top_features_opti_df
# Out:
#                      BayesianOpti Feature  BayesianOpti Importance
# 0     Curricular units 2nd sem (approved)                 0.263924
# 1                 Tuition fees up to date                 0.052622
# 2                       Age at enrollment                 0.018354
# 3     Curricular units 1st sem (approved)                 0.013110
# 4  Curricular units 1st sem (evaluations)                 0.012025
# 5     Curricular units 2nd sem (enrolled)                 0.011844
# 6                          Inflation rate                 0.010217
# 7  Curricular units 2nd sem (evaluations)                 0.009403
# 8          Previous qualification (grade)                 0.007866
# 9                         Admission grade                 0.007414

# %% [markdown]
# # Summary

# %% [markdown]
# ## Accuracy and Inference Time

# %%
pd.DataFrame(
    {
        'AutoML':[ensemble_accuracy, ensemble_inference_time],
        'BayesianOpti':[final_accuracy, optimized_inference_time]
    },
    index=['Accuracy', 'Inference Time']
)
# Out:
#                   AutoML  BayesianOpti
# Accuracy        0.758590      0.772152
# Inference Time  0.390544      0.021266

# %% [markdown]
# ## Top 10 Feature based on Permutation Importance

# %%
pd.concat([top_features_auto_df, top_features_opti_df], axis=1)
# Out:
#                            AutoML Feature  AutoML importance  \
# 0     Curricular units 2nd sem (approved)           0.173689
# 1     Curricular units 1st sem (approved)           0.042315
# 2                 Tuition fees up to date           0.041230
# 3        Curricular units 2nd sem (grade)           0.013653
# 4     Curricular units 2nd sem (enrolled)           0.005787
# 5  Curricular units 2nd sem (evaluations)          -0.005787
# 6                  Father's qualification          -0.005154
# 7                       Age at enrollment           0.004973
# 8                               Displaced          -0.004521
# 9                                  Gender          -0.004250
#
#                      BayesianOpti Feature  BayesianOpti Importance
# 0     Curricular units 2nd sem (approved)                 0.263924
# 1                 Tuition fees up to date                 0.052622
# 2                       Age at enrollment                 0.018354
# 3     Curricular units 1st sem (approved)                 0.013110
# 4  Curricular units 1st sem (evaluations)                 0.012025
# 5     Curricular units 2nd sem (enrolled)                 0.011844
# 6                          Inflation rate                 0.010217
# 7  Curricular units 2nd sem (evaluations)                 0.009403
# 8          Previous qualification (grade)                 0.007866
# 9                         Admission grade                 0.007414

# %% [markdown]
# ## Confusion Matrices

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_ensemble)).plot()
plt.title('Confusion Matrix for AutoML');

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, opt.predict(X_test_prep))).plot()
plt.title('Confusion Matrix for BayesianOpti');

# %% [markdown]
# From the summary, it is observed that the model with Bayesian optimization (using Optuna) has a higher accuracy for the test data and has less inference time when compared to the model generated using AutoML (using Auto-Sklearn).
#
# Upon checking the top10 features that has the highest feature importance (based from permutation_importance), the feature "Curricular units 2nd sem (approved)" is both the strongest identifier if the student will Dropout, Graduate, or Enroll.
